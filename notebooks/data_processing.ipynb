# %% [markdown]
# # Project on Mastodon
# Sebastian Gottschalk, Kerstin Kirchgässner, Rusen Yasar

# %% [markdown]
# # Data processing
# The primary objective of this notebook is to turn the json-formatted data into data frames.

# %%
import pandas as pd
import json

# %% [markdown]
# ## Data frame for statuses
# Read files:

# %%
with open("../data/raw/trending_statuses_1530.txt") as json_file:
    js_status_1 = json.load(json_file)
with open("../data/raw/trending_statuses_1930.txt") as json_file:
    js_status_2 = json.load(json_file)
with open("../data/raw/trending_statuses_2355.txt") as json_file:
    js_status_3 = json.load(json_file)

# %% [markdown]
# These should be flattened as data were fetched in batches. At the first level, each value is a list, and each item of these lists is a status.

# %%
status_list_of_dicts = []

for key in js_status_1:
    status_list_of_dicts += js_status_1[key]
for key in js_status_2:
    status_list_of_dicts += js_status_2[key]
for key in js_status_3:
    status_list_of_dicts += js_status_3[key]

# %%
df_status = pd.json_normalize(status_list_of_dicts, sep="_")

# %%
df_status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 75 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        4424 non-null   object
#  1   created_at                4424 non-null   object
#  2   in_reply_to_id            0 non-null      object
#  3   in_reply_to_account_id    0 non-null      object
#  4   sensitive                 4424 non-null   bool
#  5   spoiler_text              4424 non-null   object
#  6   visibility                4424 non-null   object
#  7   language                  4424 non-null   object
#  8   uri                       4424 non-null   object
#  9   url                       4424 non-null   object
#  10  replies_count             4424 non-null   int64
#  11  reblogs_count             4424 non-null   int64
#  12  favourites_count          4424 non-null   int64
#  13  edited_at                 427 non-null    object
#  14  content                   4424 non-null   object
#  15  reblog                    0 non-null      object
#  16  media_attachments         4424 non-null   object
#  17  mentions                  4424 non-null   object
#  18  tags                      4424 non-null   object
#  19  emojis                    4424 non-null   object
#  20  card                      0 non-null      float64
#  21  poll                      0 non-null      float64
#  22  account_id                4424 non-null   object
#  23  account_username          4424 non-null   object
#  24  account_acct              4424 non-null   object
#  25  account_display_name      4424 non-null   object
#  26  account_locked            4424 non-null   bool
#  27  account_bot               4424 non-null   bool
#  28  account_discoverable      4424 non-null   bool
#  29  account_indexable         4424 non-null   bool
#  30  account_group             4424 non-null   bool
#  31  account_created_at        4424 non-null   object
#  32  account_note              4424 non-null   object
#  33  account_url               4424 non-null   object
#  34  account_uri               4424 non-null   object
#  35  account_avatar            4424 non-null   object
#  36  account_avatar_static     4424 non-null   object
#  37  account_header            4424 non-null   object
#  38  account_header_static     4424 non-null   object
#  39  account_followers_count   4424 non-null   int64
#  40  account_following_count   4424 non-null   int64
#  41  account_statuses_count    4424 non-null   int64
#  42  account_last_status_at    4424 non-null   object
#  43  account_hide_collections  4379 non-null   object
#  44  account_emojis            4424 non-null   object
#  45  account_fields            4424 non-null   object
#  46  application_name          1243 non-null   object
#  47  application_website       613 non-null    object
#  48  account_noindex           1360 non-null   object
#  49  account_roles             1360 non-null   object
#  50  card_url                  1657 non-null   object
#  51  card_title                1657 non-null   object
#  52  card_description          1657 non-null   object
#  53  card_language             1481 non-null   object
#  54  card_type                 1657 non-null   object
#  55  card_author_name          1657 non-null   object
#  56  card_author_url           1657 non-null   object
#  57  card_provider_name        1657 non-null   object
#  58  card_provider_url         1657 non-null   object
#  59  card_html                 1657 non-null   object
#  60  card_width                1657 non-null   float64
#  61  card_height               1657 non-null   float64
#  62  card_image                1335 non-null   object
#  63  card_image_description    1657 non-null   object
#  64  card_embed_url            1657 non-null   object
#  65  card_blurhash             1339 non-null   object
#  66  card_published_at         811 non-null    object
#  67  poll_id                   10 non-null     object
#  68  poll_expires_at           10 non-null     object
#  69  poll_expired              10 non-null     object
#  70  poll_multiple             10 non-null     object
#  71  poll_votes_count          10 non-null     float64
#  72  poll_voters_count         8 non-null      float64
#  73  poll_options              10 non-null     object
#  74  poll_emojis               10 non-null     object
# dtypes: bool(6), float64(6), int64(6), object(57)
# memory usage: 2.4+ MB

# %% [markdown]
# ## Data cleaning and processing
#
# There are some columns to drop, e.g. (almost) fully null.

# %%
df_status_pr = df_status.drop(columns = [
    "in_reply_to_id", 
    "in_reply_to_account_id", 
    "reblog", 
    "card", 
    "poll", 
    "poll_id", 
    "poll_expires_at", 
    "poll_expired", 
    "poll_multiple", 
    "poll_votes_count", 
    "poll_voters_count",
    "poll_options", 
    "poll_emojis"
    ])

# %% [markdown]
# There should be duplicates, as we fetched data at three points in the same day.

# %%
df_status_pr.duplicated(subset="id", keep="last").sum()
# Out:
# 1247

# %%
df_status_pr = df_status_pr.drop_duplicates(subset="id", keep="last")
df_status_pr = df_status_pr.set_index("id")

# %% [markdown]
# ### View columns 10 by 10

# %%
df_status_pr.iloc[0:5, 0:10]
# Out:
#                                   created_at  sensitive spoiler_text  \
# id
# 112530190136511498  2024-05-30T13:07:14.460Z      False
# 112529682288720853  2024-05-30T10:58:05.315Z      False
# 112529690578217691  2024-05-30T11:00:08.000Z      False
# 112529707596827961  2024-05-30T11:04:31.487Z      False
# 112530249264146971  2024-05-30T13:21:45.000Z      False
#
#                    visibility language  \
# id
# 112530190136511498     public       en
# 112529682288720853     public       en
# 112529690578217691     public       en
# 112529707596827961     public       en
# 112530249264146971     public       en
#
#                                                                   uri  \
# id
# 112530190136511498  https://mastodon.social/users/GottaLaff/status...
# 112529682288720853  https://mastodon.social/users/arstechnica/stat...
# 112529690578217691  https://mastodon.world/users/auschwitzmuseum/s...
# 112529707596827961  https://mastodon.social/users/gamingonlinux/st...
# 112530249264146971  https://universeodon.com/users/georgetakei/sta...
#
#                                                                   url  \
# id
# 112530190136511498  https://mastodon.social/@GottaLaff/11253019013...
# 112529682288720853  https://mastodon.social/@arstechnica/112529682...
# 112529690578217691  https://mastodon.world/@auschwitzmuseum/112529...
# 112529707596827961  https://mastodon.social/@gamingonlinux/1125297...
# 112530249264146971  https://universeodon.com/@georgetakei/11253024...
#
#                     replies_count  reblogs_count  favourites_count
# id
# 112530190136511498              7             64                45
# 112529682288720853              3             37                43
# 112529690578217691              3             45                 8
# 112529707596827961              1             11                28
# 112530249264146971              5             10                10

# %%
df_status_pr.iloc[0:5, 10:20]
# Out:
#                    edited_at  \
# id
# 112530190136511498      None
# 112529682288720853      None
# 112529690578217691      None
# 112529707596827961      None
# 112530249264146971      None
#
#                                                               content  \
# id
# 112530190136511498  <p>The amazing Jamie <a href="https://mastodon...
# 112529682288720853  <p>Researchers get modern marines to test Anci...
# 112529690578217691  <p>30 maja 1939 | A Dutch Jewish girl, Emma va...
# 112529707596827961  <p>Athena Crisis looks a lot like Advanced War...
# 112530249264146971                          <p>Talk about clingy!</p>
#
#                                                     media_attachments  \
# id
# 112530190136511498                                                 []
# 112529682288720853  [{'id': '112529682187857378', 'type': 'image',...
# 112529690578217691  [{'id': '112529690524209257', 'type': 'image',...
# 112529707596827961  [{'id': '112529707478655427', 'type': 'image',...
# 112530249264146971  [{'id': '112530249198104425', 'type': 'image',...
#
#                    mentions  \
# id
# 112530190136511498       []
# 112529682288720853       []
# 112529690578217691       []
# 112529707596827961       []
# 112530249264146971       []
#
#                                                                  tags emojis  \
# id
# 112530190136511498  [{'name': 'raskin', 'url': 'https://mastodon.s...     []
# 112529682288720853                                                 []     []
# 112529690578217691                                                 []     []
# 112529707596827961  [{'name': 'opensource', 'url': 'https://mastod...     []
# 112530249264146971                                                 []     []
#
#                             account_id account_username  \
# id
# 112530190136511498  109253075745809751        GottaLaff
# 112529682288720853  110266162634306901      arstechnica
# 112529690578217691  109363522574341875  auschwitzmuseum
# 112529707596827961               10947    gamingonlinux
# 112530249264146971  109355700962815786      georgetakei
#
#                                       account_acct  \
# id
# 112530190136511498                       GottaLaff
# 112529682288720853                     arstechnica
# 112529690578217691  auschwitzmuseum@mastodon.world
# 112529707596827961                   gamingonlinux
# 112530249264146971    georgetakei@universeodon.com
#
#                               account_display_name
# id
# 112530190136511498                           Laffy
# 112529682288720853                    Ars Technica
# 112529690578217691              Auschwitz Memorial
# 112529707596827961         Liam @ GamingOnLinux 🐧🎮
# 112530249264146971  George Takei :verified: 🏳️‍🌈🖖🏽

# %%
bool_list = []
for men in df_status_pr["mentions"]: 
    bool_list.append(len(men) > 0)
sum(bool_list)
# Out:
# 275

# %%
df_status_pr.iloc[0:5, 20:30]
# Out:
#                     account_locked  account_bot  account_discoverable  \
# id
# 112530190136511498           False        False                  True
# 112529682288720853           False        False                  True
# 112529690578217691           False        False                  True
# 112529707596827961           False        False                  True
# 112530249264146971           False        False                  True
#
#                     account_indexable  account_group  \
# id
# 112530190136511498               True          False
# 112529682288720853              False          False
# 112529690578217691              False          False
# 112529707596827961               True          False
# 112530249264146971              False          False
#
#                           account_created_at  \
# id
# 112530190136511498  2022-10-29T00:00:00.000Z
# 112529682288720853  2023-04-26T00:00:00.000Z
# 112529690578217691  2022-11-18T00:00:00.000Z
# 112529707596827961  2016-11-21T00:00:00.000Z
# 112530249264146971  2022-11-15T00:00:00.000Z
#
#                                                          account_note  \
# id
# 112530190136511498  <p>Bite me, Musk.</p><p>Progressive political ...
# 112529682288720853  <p>Original news, reviews, analysis of tech tr...
# 112529690578217691  <p>Former German Nazi concentration &amp; exte...
# 112529707596827961  <p>News + Spicy Opinions. One person mostly. C...
# 112530249264146971  <p>I boldly went to this new site. Follow for ...
#
#                                                 account_url  \
# id
# 112530190136511498       https://mastodon.social/@GottaLaff
# 112529682288720853     https://mastodon.social/@arstechnica
# 112529690578217691  https://mastodon.world/@auschwitzmuseum
# 112529707596827961   https://mastodon.social/@gamingonlinux
# 112530249264146971    https://universeodon.com/@georgetakei
#
#                                                      account_uri  \
# id
# 112530190136511498       https://mastodon.social/users/GottaLaff
# 112529682288720853     https://mastodon.social/users/arstechnica
# 112529690578217691  https://mastodon.world/users/auschwitzmuseum
# 112529707596827961   https://mastodon.social/users/gamingonlinux
# 112530249264146971    https://universeodon.com/users/georgetakei
#
#                                                        account_avatar
# id
# 112530190136511498  https://files.mastodon.social/accounts/avatars...
# 112529682288720853  https://files.mastodon.social/accounts/avatars...
# 112529690578217691  https://files.mastodon.social/cache/accounts/a...
# 112529707596827961  https://files.mastodon.social/accounts/avatars...
# 112530249264146971  https://files.mastodon.social/cache/accounts/a...

# %%
df_status_pr.iloc[0:5, 30:40]
# Out:
#                                                 account_avatar_static  \
# id
# 112530190136511498  https://files.mastodon.social/accounts/avatars...
# 112529682288720853  https://files.mastodon.social/accounts/avatars...
# 112529690578217691  https://files.mastodon.social/cache/accounts/a...
# 112529707596827961  https://files.mastodon.social/accounts/avatars...
# 112530249264146971  https://files.mastodon.social/cache/accounts/a...
#
#                                                        account_header  \
# id
# 112530190136511498  https://files.mastodon.social/accounts/headers...
# 112529682288720853  https://files.mastodon.social/accounts/headers...
# 112529690578217691  https://files.mastodon.social/cache/accounts/h...
# 112529707596827961  https://files.mastodon.social/accounts/headers...
# 112530249264146971  https://files.mastodon.social/cache/accounts/h...
#
#                                                 account_header_static  \
# id
# 112530190136511498  https://files.mastodon.social/accounts/headers...
# 112529682288720853  https://files.mastodon.social/accounts/headers...
# 112529690578217691  https://files.mastodon.social/cache/accounts/h...
# 112529707596827961  https://files.mastodon.social/accounts/headers...
# 112530249264146971  https://files.mastodon.social/cache/accounts/h...
#
#                     account_followers_count  account_following_count  \
# id
# 112530190136511498                    24284                     6108
# 112529682288720853                   154555                        6
# 112529690578217691                    91548                       43
# 112529707596827961                    60419                      239
# 112530249264146971                   422997                       35
#
#                     account_statuses_count account_last_status_at  \
# id
# 112530190136511498                   92375             2024-05-30
# 112529682288720853                    4635             2024-05-30
# 112529690578217691                    2030             2024-05-30
# 112529707596827961                   11213             2024-05-30
# 112530249264146971                    5380             2024-05-30
#
#                    account_hide_collections  \
# id
# 112530190136511498                    False
# 112529682288720853                    False
# 112529690578217691                    False
# 112529707596827961                    False
# 112530249264146971                    False
#
#                                                        account_emojis  \
# id
# 112530190136511498                                                 []
# 112529682288720853                                                 []
# 112529690578217691                                                 []
# 112529707596827961                                                 []
# 112530249264146971  [{'shortcode': 'verified', 'url': 'https://fil...
#
#                                                        account_fields
# id
# 112530190136511498  [{'name': 'WEBSITE', 'value': '<a href="https:...
# 112529682288720853  [{'name': 'Ars Technica', 'value': '<a href="h...
# 112529690578217691  [{'name': 'Website', 'value': '<a href="https:...
# 112529707596827961  [{'name': 'Website', 'value': '<a href="https:...
# 112530249264146971  [{'name': 'Instagram', 'value': '<a href="http...

# %%
df_status_pr.iloc[0:5, 40:50]
# Out:
#                        application_name               application_website  \
# id
# 112530190136511498      Mona for iPhone  https://mastodon.social/@MonaApp
# 112529682288720853  Bot Posts (testing)           https://arstechnica.com
# 112529690578217691                  NaN                               NaN
# 112529707596827961               Buffer                https://buffer.com
# 112530249264146971                  NaN                               NaN
#
#                    account_noindex account_roles  \
# id
# 112530190136511498           False            []
# 112529682288720853           False            []
# 112529690578217691             NaN           NaN
# 112529707596827961           False            []
# 112530249264146971             NaN           NaN
#
#                                                              card_url  \
# id
# 112530190136511498  https://www.nytimes.com/2024/05/29/opinion/ali...
# 112529682288720853  https://arstechnica.com/science/2024/05/resear...
# 112529690578217691                                                NaN
# 112529707596827961  https://www.gamingonlinux.com/2024/05/athena-c...
# 112530249264146971                                                NaN
#
#                                                            card_title  \
# id
# 112530190136511498  Opinion | How to Force Justices Alito and Thom...
# 112529682288720853  Bizarre armor from Mycenaean Greece turns out ...
# 112529690578217691                                                NaN
# 112529707596827961  Athena Crisis looks a lot like Advanced Wars a...
# 112530249264146971                                                NaN
#
#                                                      card_description  \
# id
# 112530190136511498  Can they really decide for themselves whether ...
# 112529682288720853  People suspected the Dendra armor was ceremoni...
# 112529690578217691                                                NaN
# 112529707596827961  Entering Early Access on Steam back in March, ...
# 112530249264146971                                                NaN
#
#                    card_language card_type card_author_name
# id
# 112530190136511498            en      link     Jamie Raskin
# 112529682288720853            en      link
# 112529690578217691           NaN       NaN              NaN
# 112529707596827961            en      link        Liam Dawe
# 112530249264146971           NaN       NaN              NaN

# %%
df_status_pr.iloc[0:5, 50:]
# Out:
#                                                  card_author_url  \
# id
# 112530190136511498       https://www.nytimes.com/by/jamie-raskin
# 112529682288720853
# 112529690578217691                                           NaN
# 112529707596827961  https://www.gamingonlinux.com/profiles/liamd
# 112530249264146971                                           NaN
#
#                     card_provider_name card_provider_url card_html  \
# id
# 112530190136511498  The New York Times
# 112529682288720853        Ars Technica
# 112529690578217691                 NaN               NaN       NaN
# 112529707596827961       GamingOnLinux
# 112530249264146971                 NaN               NaN       NaN
#
#                     card_width  card_height  \
# id
# 112530190136511498      1050.0        550.0
# 112529682288720853       640.0        386.0
# 112529690578217691         NaN          NaN
# 112529707596827961       740.0        420.0
# 112530249264146971         NaN          NaN
#
#                                                            card_image  \
# id
# 112530190136511498  https://files.mastodon.social/cache/preview_ca...
# 112529682288720853  https://files.mastodon.social/cache/preview_ca...
# 112529690578217691                                                NaN
# 112529707596827961  https://files.mastodon.social/cache/preview_ca...
# 112530249264146971                                                NaN
#
#                    card_image_description card_embed_url  \
# id
# 112530190136511498
# 112529682288720853
# 112529690578217691                    NaN            NaN
# 112529707596827961
# 112530249264146971                    NaN            NaN
#
#                                            card_blurhash  \
# id
# 112530190136511498  UCIYB|~pD%%M9F?bM|M{%MkBIUMx_NWBM{M{
# 112529682288720853  UbECaq02s:xsS7n#ofRkxsRkj[oebIocazfQ
# 112529690578217691                                   NaN
# 112529707596827961  U7HC3rGFpk-z3txpvEnj]p%YO*n7-Do]R+Rm
# 112530249264146971                                   NaN
#
#                            card_published_at
# id
# 112530190136511498  2024-05-29T18:26:00.000Z
# 112529682288720853  2024-05-30T10:55:57.000Z
# 112529690578217691                       NaN
# 112529707596827961  2024-05-30T11:03:39.000Z
# 112530249264146971                       NaN

# %% [markdown]
# ### Processing tags column
#
# Make tags more usable. First, count.

# %%
df_status_pr["tags_num"] = df_status_pr["tags"].map(lambda x: len(x))

# %% [markdown]
# Next, concatenate tags into a single string.

# %%
def dict_names_to_string(ls_of_dt):
    tag_name = " "
    for dt in ls_of_dt:
        tag_name += dt["name"] + " "
    return tag_name.strip()

# %%
df_status_pr["tags_str"] = df_status_pr["tags"].map(dict_names_to_string)

# %% [markdown]
# ### Processing date-times

# %%
from datetime import datetime

# %%
df_status_pr["created_at_dt"] = df_status_pr["created_at"].map(
    lambda dt_str: datetime.strptime(dt_str, "%Y-%m-%dT%H:%M:%S.%fZ") if type(dt_str) == str else None
    )
df_status_pr["edited_at_dt"] = df_status_pr["edited_at"].map(
    lambda dt_str: datetime.strptime(dt_str, "%Y-%m-%dT%H:%M:%S.%fZ") if type(dt_str) == str else None
    )
df_status_pr["account_created_at_dt"] = df_status_pr["account_created_at"].map(
    lambda dt_str: datetime.strptime(dt_str, "%Y-%m-%dT%H:%M:%S.%fZ") if type(dt_str) == str else None
    )
df_status_pr["account_last_status_at"] = df_status_pr["account_last_status_at"].map(
    lambda dt_str: datetime.strptime(dt_str, "%Y-%m-%d") if type(dt_str) == str else None
    )
df_status_pr["card_published_at_dt"] = df_status_pr["card_published_at"].map(
    lambda dt_str: datetime.strptime(dt_str, "%Y-%m-%dT%H:%M:%S.%fZ") if type(dt_str) == str else None
    )

# %% [markdown]
# One useful information could be account age.

# %%
df_status_pr["account_age"] = df_status_pr["account_created_at_dt"].map(
    lambda dt: (datetime.today() - dt).days
)

# %% [markdown]
# ### Media, mentions, emojis, card

# %% [markdown]
# Count media attachments, code if any media attached

# %%
df_status_pr["media_count"] = df_status_pr["media_attachments"].map(lambda ls: len(ls))
df_status_pr["any_media"] = df_status_pr["media_count"].map(lambda ct: 1 if ct>0 else 0)

# %% [markdown]
# Count mentions, code if any mention present

# %%
df_status_pr["mention_count"] = df_status_pr["mentions"].map(lambda ls: len(ls))
df_status_pr["any_mention"] = df_status_pr["mention_count"].map(lambda ct: 1 if ct>0 else 0)

# %% [markdown]
# Count emojis, code if any emoji present

# %%
df_status_pr["emoji_count"] = df_status_pr["emojis"].map(lambda ls: len(ls))
df_status_pr["any_emoji"] = df_status_pr["emoji_count"].map(lambda ct: 1 if ct>0 else 0)

# %% [markdown]
# Check cards

# %%
df_status_pr["card_type"].value_counts()
# Out:
# card_type
# link     1097
# video      66
# photo       2
# Name: count, dtype: int64

# %% [markdown]
# Categorise again, map null values to another category

# %%
def card_categorise(card_type): 
    cat = "No card"
    if card_type == "link":
        cat = "link"
    elif card_type == "video":
        cat = "video/photo"
    elif card_type == "photo":
        cat = "video/photo"
    return cat

# %%
df_status_pr["card_categories"] = df_status_pr["card_type"].map(card_categorise)

# %%
df_status_pr["card_categories"].value_counts()
# Out:
# card_categories
# No card        2012
# link           1097
# video/photo      68
# Name: count, dtype: int64

# %% [markdown]
# Another variable if there is any card

# %%
df_status_pr["any_card"] = df_status_pr["card_categories"].map(lambda cat: 0 if cat == "No card" else 1)

# %% [markdown]
# ## Tags data

# %% [markdown]
# Read file

# %%
with open("../data/raw/trending_tags_2355.txt") as json_file:
    js_tags = json.load(json_file)

# %%
df_tags = pd.json_normalize(js_tags)

# %%
df_tags_long = df_tags.explode("history")

# %% [markdown]
# Now there are 7 entries for each tag, and some info to unpack from the history column.

# %%
import numpy as np
days_before = np.tile(np.arange(0,7), df_tags_long.shape[0] // 7)

df_tags_long["days_before"] = days_before

# %%
df_tags_long["accounts_using"] = df_tags_long["history"].map(lambda dt : dt["accounts"])
df_tags_long["usage_count"] = df_tags_long["history"].map(lambda dt : dt["uses"])

# %%
df_tags_long = df_tags_long.drop(columns = "history")

# %%
df_tags_long
# Out:
#                   name                                              url  \
# 0           musiquinta          https://mastodon.social/tags/musiquinta
# 0           musiquinta          https://mastodon.social/tags/musiquinta
# 0           musiquinta          https://mastodon.social/tags/musiquinta
# 0           musiquinta          https://mastodon.social/tags/musiquinta
# 0           musiquinta          https://mastodon.social/tags/musiquinta
# ..                 ...                                              ...
# 19  TheUmbrellaAcademy  https://mastodon.social/tags/theumbrellaacademy
# 19  TheUmbrellaAcademy  https://mastodon.social/tags/theumbrellaacademy
# 19  TheUmbrellaAcademy  https://mastodon.social/tags/theumbrellaacademy
# 19  TheUmbrellaAcademy  https://mastodon.social/tags/theumbrellaacademy
# 19  TheUmbrellaAcademy  https://mastodon.social/tags/theumbrellaacademy
#
#     days_before accounts_using usage_count
# 0             0             92         226
# 0             1              2           2
# 0             2              2           2
# 0             3              1           2
# 0             4              1           1
# ..          ...            ...         ...
# 19            2              0           0
# 19            3              0           0
# 19            4              0           0
# 19            5              0           0
# 19            6              0           0
#
# [140 rows x 5 columns]

# %% [markdown]
# ## Save files for further use

# %%
df_status_pr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3177 entries, 112530190136511498 to 112530897905137155
# Data columns (total 76 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   created_at                3177 non-null   object
#  1   sensitive                 3177 non-null   bool
#  2   spoiler_text              3177 non-null   object
#  3   visibility                3177 non-null   object
#  4   language                  3177 non-null   object
#  5   uri                       3177 non-null   object
#  6   url                       3177 non-null   object
#  7   replies_count             3177 non-null   int64
#  8   reblogs_count             3177 non-null   int64
#  9   favourites_count          3177 non-null   int64
#  10  edited_at                 309 non-null    object
#  11  content                   3177 non-null   object
#  12  media_attachments         3177 non-null   object
#  13  mentions                  3177 non-null   object
#  14  tags                      3177 non-null   object
#  15  emojis                    3177 non-null   object
#  16  account_id                3177 non-null   object
#  17  account_username          3177 non-null   object
#  18  account_acct              3177 non-null   object
#  19  account_display_name      3177 non-null   object
#  20  account_locked            3177 non-null   bool
#  21  account_bot               3177 non-null   bool
#  22  account_discoverable      3177 non-null   bool
#  23  account_indexable         3177 non-null   bool
#  24  account_group             3177 non-null   bool
#  25  account_created_at        3177 non-null   object
#  26  account_note              3177 non-null   object
#  27  account_url               3177 non-null   object
#  28  account_uri               3177 non-null   object
#  29  account_avatar            3177 non-null   object
#  30  account_avatar_static     3177 non-null   object
#  31  account_header            3177 non-null   object
#  32  account_header_static     3177 non-null   object
#  33  account_followers_count   3177 non-null   int64
#  34  account_following_count   3177 non-null   int64
#  35  account_statuses_count    3177 non-null   int64
#  36  account_last_status_at    3177 non-null   datetime64[ns]
#  37  account_hide_collections  3143 non-null   object
#  38  account_emojis            3177 non-null   object
#  39  account_fields            3177 non-null   object
#  40  application_name          890 non-null    object
#  41  application_website       446 non-null    object
#  42  account_noindex           976 non-null    object
#  43  account_roles             976 non-null    object
#  44  card_url                  1165 non-null   object
#  45  card_title                1165 non-null   object
#  46  card_description          1165 non-null   object
#  47  card_language             1040 non-null   object
#  48  card_type                 1165 non-null   object
#  49  card_author_name          1165 non-null   object
#  50  card_author_url           1165 non-null   object
#  51  card_provider_name        1165 non-null   object
#  52  card_provider_url         1165 non-null   object
#  53  card_html                 1165 non-null   object
#  54  card_width                1165 non-null   float64
#  55  card_height               1165 non-null   float64
#  56  card_image                944 non-null    object
#  57  card_image_description    1165 non-null   object
#  58  card_embed_url            1165 non-null   object
#  59  card_blurhash             947 non-null    object
#  60  card_published_at         587 non-null    object
#  61  tags_num                  3177 non-null   int64
#  62  tags_str                  3177 non-null   object
#  63  created_at_dt             3177 non-null   datetime64[ns]
#  64  edited_at_dt              309 non-null    datetime64[ns]
#  65  account_created_at_dt     3177 non-null   datetime64[ns]
#  66  card_published_at_dt      587 non-null    datetime64[ns]
#  67  account_age               3177 non-null   int64
#  68  media_count               3177 non-null   int64
#  69  any_media                 3177 non-null   int64
#  70  mention_count             3177 non-null   int64
#  71  any_mention               3177 non-null   int64
#  72  emoji_count               3177 non-null   int64
#  73  any_emoji                 3177 non-null   int64
#  74  card_categories           3177 non-null   object
#  75  any_card                  3177 non-null   int64
# dtypes: bool(6), datetime64[ns](5), float64(2), int64(15), object(48)
# memory usage: 1.7+ MB

# %%
df_status_pr.to_csv("../data/processed/trending_statuses.csv")

# %%
df_tags.to_csv("../data/processed/trending_tags.csv")
